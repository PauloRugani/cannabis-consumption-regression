# %% [markdown]
# Data Normality
#
# - Histplot
# - Q-Q plot
#
# - Normality tests:
#     - Shapiro-Wilk
#     - Lilliefors
#
# - Normality test result:
#
#     - Ho = Normal distribution : p > 0.05
#     - Ha = distribution != normal : p <= 0.05

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('../data/processed/2_data_cleaning.csv', sep=',')
df.head(3)
# Out:
#     Age  Education   Nscore   Escore   Oscore   AScore   Cscore  Impulsive  \
# 0  39.5          1  0.31287 -0.57545 -0.58331 -0.91699 -0.00665   -0.21712
# 1  29.5          0 -0.67825  1.93886  1.43533  0.76096 -0.14277   -0.71126
# 2  39.5          6 -0.46725  0.80523 -0.84732 -1.62090 -1.01450   -1.37983
#
#         SS  Cannabis
# 0 -1.18084         0
# 1 -0.21575         4
# 2  0.40148         3

# %%
for col in df.columns:
  fig, ax = plt.subplots(1, 2, figsize=(14, 6))
  ax[0].hist(df[col], bins=30);
  ax[0].set_title(f'Histogram {col}')
  stats.probplot(df[col], dist='norm', plot=ax[1]);
  ax[1].set_title(f'Q-Q Plot {col}')

# %% [markdown]
# ## Shapiro-Wilk Test

# %%
for col in df.columns:
  stat, p = stats.shapiro(df[col])
  if p > 0.05:
    print(f'{col} is normal distribution: {p}')
  else:
    print(f'{col} is not normal distribution: {p}')
# Out:
# Age is not normal distribution: 2.9052925211966915e-38
# Education is not normal distribution: 1.338982474448715e-41
# Nscore is normal distribution: 0.16671561302845556
# Escore is not normal distribution: 0.012959100010292098
# Oscore is not normal distribution: 0.0030371706988500807
# AScore is not normal distribution: 0.010646466932122184
# Cscore is not normal distribution: 0.01828180920018784
# Impulsive is not normal distribution: 7.694145044769784e-21
# SS is not normal distribution: 2.4747351191072738e-17
# Cannabis is not normal distribution: 2.0502490075426726e-37
