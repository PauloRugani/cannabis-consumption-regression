# %% [markdown]
# Data Normality
#
# - Histplot
# - Q-Q plot
#
# - Normality tests:
#     - Shapiro-Wilk
#     - Lilliefors
#
# - Normality test result:
#
#     - Ho = Normal distribution : p > 0.05
#     - Ha = distribution != normal : p <= 0.05

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('../data/processed/2_data_cleaning.csv', sep=',')
df.head(3)
# Out:
#     Age  Education   Nscore   Escore   Oscore   AScore   Cscore  Impulsive  \
# 0  29.5          0 -0.67825  1.93886  1.43533  0.76096 -0.14277   -0.71126
# 1  39.5          6 -0.46725  0.80523 -0.84732 -1.62090 -1.01450   -1.37983
# 2  21.0          5 -0.14882 -0.80615 -0.01928  0.59042  0.58489   -1.37983
#
#         SS  Cannabis
# 0 -0.21575         4
# 1  0.40148         3
# 2 -1.18084         2

# %%
for col in df.columns:
  fig, ax = plt.subplots(1, 2, figsize=(14, 6))
  ax[0].hist(df[col], bins=30);
  ax[0].set_title(f'Histogram {col}')
  stats.probplot(df[col], dist='norm', plot=ax[1]);
  ax[1].set_title(f'Q-Q Plot {col}')

# %% [markdown]
# ## Shapiro-Wilk Test

# %%
for col in df.columns:
  stat, p = stats.shapiro(df[col])
  if p > 0.05:
    print(f'{col} is normal distribution: {p}')
  else:
    print(f'{col} is not normal distribution: {p}')
# Out:
# Age is not normal distribution: 2.8668976810514304e-38
# Education is not normal distribution: 1.3417828877404583e-41
# Nscore is normal distribution: 0.16672756449223736
# Escore is not normal distribution: 0.012988067753074614
# Oscore is not normal distribution: 0.0030390195848804765
# AScore is not normal distribution: 0.010687717017922047
# Cscore is not normal distribution: 0.01834561337300372
# Impulsive is not normal distribution: 7.785145334070611e-21
# SS is not normal distribution: 2.4936071994930594e-17
# Cannabis is not normal distribution: 2.134766983960643e-37
