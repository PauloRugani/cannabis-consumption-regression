# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/Drug_Consumption.csv', sep=',')
df.head(3)
# Out:
#    ID    Age Gender                          Education Country Ethnicity  \
# 0   2  25-34      M                   Doctorate degree      UK     White
# 1   3  35-44      M  Professional certificate/ diploma      UK     White
# 2   4  18-24      F                     Masters degree      UK     White
#
#     Nscore   Escore   Oscore   AScore  ...  Ecstasy  Heroin  Ketamine Legalh  \
# 0 -0.67825  1.93886  1.43533  0.76096  ...      CL4     CL0       CL2    CL0
# 1 -0.46725  0.80523 -0.84732 -1.62090  ...      CL0     CL0       CL0    CL0
# 2 -0.14882 -0.80615 -0.01928  0.59042  ...      CL0     CL0       CL2    CL0
#
#    LSD Meth Mushrooms Nicotine Semer  VSA
# 0  CL2  CL3       CL0      CL4   CL0  CL0
# 1  CL0  CL0       CL1      CL0   CL0  CL0
# 2  CL0  CL0       CL0      CL2   CL0  CL0
#
# [3 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Education', 'Country', 'Ethnicity', 'Nscore',
#        'Escore', 'Oscore', 'AScore', 'Cscore', 'Impulsive', 'SS', 'Alcohol',
#        'Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack',
#        'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms',
#        'Nicotine', 'Semer', 'VSA'],
#       dtype='object')

# %%
df = df[['Age', 'Education', 'Nscore', 'Escore', 'Oscore', 'AScore', 'Cscore', 'Impulsive',
        'SS', 'Alcohol', 'Cannabis', 'Coke', 'Crack', 'Ecstasy', 'LSD', 'Nicotine']]
df.columns
# Out:
# Index(['Age', 'Education', 'Nscore', 'Escore', 'Oscore', 'AScore', 'Cscore',
#        'Impulsive', 'SS', 'Alcohol', 'Cannabis', 'Coke', 'Crack', 'Ecstasy',
#        'LSD', 'Nicotine'],
#       dtype='object')

# %%
def parse_age(age_str):
    if '+' in age_str:
        return int(age_str.replace('+', ''))
    return round((sum(list(map(int, age_str.split('-')))) / 2), 1)


df['Age'] = df['Age'].apply(parse_age)

# %%
df.head(1)
# Out:
#     Age         Education   Nscore   Escore   Oscore   AScore   Cscore  \
# 0  29.5  Doctorate degree -0.67825  1.93886  1.43533  0.76096 -0.14277
#
#    Impulsive       SS Alcohol Cannabis Coke Crack Ecstasy  LSD Nicotine
# 0   -0.71126 -0.21575     CL5      CL4  CL3   CL0     CL4  CL2      CL4

# %%
df['Education'].value_counts()
# Out:
# Education
# Some college or university, no certificate or degree    506
# University degree                                       480
# Masters degree                                          283
# Professional certificate/ diploma                       269
# Left school at 18 years                                 100
# Left school at 16 years                                  99
# Doctorate degree                                         89
# Left school at 17 years                                  30
# Left school before 16 years                              28
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
endocer = LabelEncoder()
df['Education'] = endocer.fit_transform(df['Education'])
df.head()
# Out:
#     Age  Education   Nscore   Escore   Oscore   AScore   Cscore  Impulsive  \
# 0  29.5          0 -0.67825  1.93886  1.43533  0.76096 -0.14277   -0.71126
# 1  39.5          6 -0.46725  0.80523 -0.84732 -1.62090 -1.01450   -1.37983
# 2  21.0          5 -0.14882 -0.80615 -0.01928  0.59042  0.58489   -1.37983
# 3  39.5          0  0.73545 -1.63340 -0.45174 -0.30172  1.30612   -0.21712
# 4  65.0          3 -0.67825 -0.30033 -1.55521  2.03972  1.63088   -1.37983
#
#         SS Alcohol Cannabis Coke Crack Ecstasy  LSD Nicotine
# 0 -0.21575     CL5      CL4  CL3   CL0     CL4  CL2      CL4
# 1  0.40148     CL6      CL3  CL0   CL0     CL0  CL0      CL0
# 2 -1.18084     CL4      CL2  CL2   CL0     CL0  CL0      CL2
# 3 -0.21575     CL4      CL3  CL0   CL0     CL1  CL0      CL2
# 4 -1.54858     CL2      CL0  CL0   CL0     CL0  CL0      CL6

# %%
labels = {
    'CL0': 0,
    'CL1': 1,
    'CL2': 2,
    'CL3': 3,
    'CL4': 4,
    'CL5': 5,
    'CL6': 6
}

columns = ['Alcohol', 'Cannabis', 'Coke', 'Crack', 'Ecstasy', 'LSD', 'Nicotine']
for col in columns:
    df[col] = df[col].map(labels)

df
# Out:
#        Age  Education   Nscore   Escore   Oscore   AScore   Cscore  Impulsive  \
# 0     29.5          0 -0.67825  1.93886  1.43533  0.76096 -0.14277   -0.71126
# 1     39.5          6 -0.46725  0.80523 -0.84732 -1.62090 -1.01450   -1.37983
# 2     21.0          5 -0.14882 -0.80615 -0.01928  0.59042  0.58489   -1.37983
# 3     39.5          0  0.73545 -1.63340 -0.45174 -0.30172  1.30612   -0.21712
# 4     65.0          3 -0.67825 -0.30033 -1.55521  2.03972  1.63088   -1.37983
# ...    ...        ...      ...      ...      ...      ...      ...        ...
# 1879  21.0          7 -1.19430  1.74091  1.88511  0.76096 -1.13788    0.88113
# 1880  21.0          7 -0.24649  1.74091  0.58331  0.76096 -1.51840    0.88113
# 1881  29.5          8  1.13281 -1.37639 -1.27553 -1.77200 -1.38502    0.52975
# 1882  21.0          7  0.91093 -1.92173  0.29338 -1.62090 -2.57309    1.29221
# 1883  21.0          7 -0.46725  2.12700  1.65653  1.11406  0.41594    0.88113
#
#            SS  Alcohol  Cannabis  Coke  Crack  Ecstasy  LSD  Nicotine
# 0    -0.21575        5         4     3      0        4    2         4
# 1     0.40148        6         3     0      0        0    0         0
# 2    -1.18084        4         2     2      0        0    0         2
# 3    -0.21575        4         3     0      0        1    0         2
# 4    -1.54858        2         0     0      0        0    0         6
# ...       ...      ...       ...   ...    ...      ...  ...       ...
# 1879  1.92173        5         5     0      0        0    3         0
# 1880  0.76540        5         3     0      0        2    5         5
# 1881 -0.52593        4         6     4      0        4    2         6
# 1882  1.22470        5         6     0      0        3    3         4
# 1883  1.22470        4         3     3      0        3    3         6
#
# [1884 rows x 16 columns]

# %%
df.describe()
# Out:
#                Age    Education       Nscore       Escore       Oscore  \
# count  1884.000000  1884.000000  1884.000000  1884.000000  1884.000000
# mean     33.424363     5.829087    -0.000119     0.000143    -0.000225
# std      12.127103     2.284233     0.998345     0.997625     0.996402
# min      21.000000     0.000000    -3.464360    -3.273930    -3.273930
# 25%      21.000000     5.000000    -0.678250    -0.695090    -0.717270
# 50%      29.500000     7.000000     0.042570     0.003320    -0.019280
# 75%      39.500000     8.000000     0.629670     0.637790     0.723300
# max      65.000000     8.000000     3.273930     3.273930     2.901610
#
#             AScore       Cscore    Impulsive           SS     Alcohol  \
# count  1884.000000  1884.000000  1884.000000  1884.000000  1884.00000
# mean      0.000242    -0.000383     0.007335    -0.002667     4.63482
# std       0.997481     0.997787     0.954674     0.963575     1.33158
# min      -3.464360    -3.464360    -2.555240    -2.078480     0.00000
# 25%      -0.606330    -0.652530    -0.711260    -0.525930     4.00000
# 50%      -0.017290    -0.006650    -0.217120     0.079870     5.00000
# 75%       0.760960     0.584890     0.529750     0.765400     6.00000
# max       3.464360     3.464360     2.901610     1.921730     6.00000
#
#           Cannabis         Coke        Crack      Ecstasy          LSD  \
# count  1884.000000  1884.000000  1884.000000  1884.000000  1884.000000
# mean      2.990977     1.161890     0.297771     1.314756     1.062102
# std       2.287007     1.513196     0.837247     1.647726     1.491298
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000     0.000000     0.000000
# 50%       3.000000     0.000000     0.000000     0.000000     0.000000
# 75%       5.000000     2.000000     0.000000     3.000000     2.000000
# max       6.000000     6.000000     6.000000     6.000000     6.000000
#
#           Nicotine
# count  1884.000000
# mean      3.201168
# std       2.414415
# min       0.000000
# 25%       1.000000
# 50%       3.000000
# 75%       6.000000
# max       6.000000

# %%
df.to_csv('../data/processed/2_data_cleaning.csv', index=False)
